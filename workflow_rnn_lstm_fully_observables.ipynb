# %% [markdown]
# The goal is this notebook is to showcase a demo of the RNN and LSTM model for the training of fully observable chaotic systems.

# %% [markdown]
# # Step 1: Import Dependencies
#
# We begin by importing all required modules:
#
# - **Standard libraries** for deep learning (`torch`, `nn`), data handling (`pandas`), and visualization (`matplotlib`)
# - **Lorenz system simulator** from `chaotic_data.systems` to generate synthetic chaotic time series
# - **Data utilities** like preprocessing and plotting helpers
# - **Model classes**: `RNN_Model` and `LSTM_Model` from the `src.models.classic` module
# - **Custom Trainer**: `RNNTrainer` which handles training, validation, and saving checkpoints

# %%
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from chaotic_data import systems  # Lorenz/chaotic system data generator
from data_utils import preprocess, plottings  # normalization, dataloaders, visualization

from src.models.classic import RNN_Model, LSTM_Model
from src.single_trainers.classic_training import RNNTrainer  # wherever your trainer is saved

# %% [markdown]
# > `src`, `chaotic_data`, and `data_utils` are modules available in the repo

# %% [markdown]
# ## Step 2: Simulate the Lorenz System
#
# We generate a synthetic multivariate time series using the Lorenz chaotic system.
#
# - The Lorenz system is a classic example of a deterministic chaotic system.
# - We specify:
#   - `start` and `stop`: the time interval for simulation
#   - `ics`: initial conditions (x=1.0, y=0.0, z=1.25)
#   - `time_grid`: simulation step size
#
# The result is a NumPy array of shape `(T, 3)` where each column represents a variable (x, y, z) over time.

# %%
lorenz_data, _ = systems.LorenzSolver(start=0.0, stop=20.0, ics=(1.0, 0.0, 1.25), time_grid=0.01)

print(lorenz_data.shape)
# Out:
# torch.Size([2000, 3])

# %% [markdown]
# ## Step 3: Normalize the Lorenz Data
#
# Before training, we normalize the Lorenz system outputs to improve convergence and stability.
#
# - We use a custom `Normalization_Strategy` provided in `data_utils.preprocess`.
# - `Scale_ToNormalize` performs **min-max scaling** or a domain-specific scaling with a custom `scaling_factor`.
# - The function returns:
#   - `scaled_lorenz`: normalized version of the data
#   - `avg_lorenz`: average vector (useful for rescaling if needed)
#
# We also truncate the dataset to the first 200 steps for a quicker training demo.

# %%
norma = preprocess.Normalization_Strategy()
scaled_lorenz, avg_lorenz = norma.Scale_ToNormalize(data=lorenz_data, scaling_factor=0.02)
scaled_lorenz = scaled_lorenz[:200]


print(scaled_lorenz.shape , avg_lorenz.shape)
# Out:
# torch.Size([200, 3]) torch.Size([3])

# %% [markdown]
# ## Step 4: Split into Training and Testing Sets
#
# To train and evaluate the model, we split the normalized data:
#
# - **Training Set**: the first 150 timesteps
# - **Testing Set**: the remaining 50 timesteps (used later for inference or visualization)
#
# This is a simple chronological split suitable for time series forecasting tasks.

# %%
train_size = 150
train_lorenz = scaled_lorenz[:train_size]
test_lorenz = scaled_lorenz[train_size:]

print(train_lorenz.shape, test_lorenz.shape)
# Out:
# torch.Size([150, 3]) torch.Size([50, 3])

# %% [markdown]
# ##  Step 5: Create Sliding Windows and a DataLoader
#
# To train sequence models like RNNs or LSTMs, we convert the time series into **overlapping input-output windows**.
#
# - `InpTarg_TSDataset.create_train_loader(...)`
#   - Automatically wraps sliding windows into a PyTorch `DataLoader`
#   - `window_size=10` creates input sequences of 10 timesteps
#   - `batch_size=5` defines how many samples per batch
#
# - `SlidingWindowDataset(...)` and `sliding_windows_shift_to(...)`
#   - Also generate sliding windows directly as a NumPy/torch array
#   - Useful for inspection, plotting, or building custom datasets

# %%
my_rnn_data_loader = preprocess.InpTarg_TSDataset.create_train_loader(
    data=train_lorenz, window_size=10, batch_size=5, shuffle=False
)

for inp_, out_ in my_rnn_data_loader:
    print(inp_.shape, out_.shape)

    break
# Out:
# torch.Size([5, 10, 3]) torch.Size([5, 10, 3])

# %%
data_sliding = preprocess.SlidingWindowDataset(data=train_lorenz, window_size=10)
sliced_data = data_sliding.sliding_windows_shift_to(train_lorenz, 10)

print(sliced_data.shape)
# Out:
# torch.Size([141, 10, 3])

# %% [markdown]
# ##  Step 6: Create Calibration and Forecast Windows
#
# For validation and forecasting tasks, we need a **calibration window** (context) and the **ground-truth future** (target):
#
# - `context_size`: how many past timesteps to use as model input
# - `fcast_size`: how many future timesteps to forecast
# - `location`:
#   - `'random_'`: sample a random forecast segment
#   - `'last_'`: use the last available portion of the time series
#
# These sequences are used by the trainer during `train_validate()` or for manual forecasting evaluation.

# %%
context_data_r, toforecast_data_r = data_sliding.contextwindow_testdata_generator(
    context_size=5, fcast_size=30, location='random_'
)

print(context_data_r.shape, toforecast_data_r.shape)
# Out:
# torch.Size([5, 3]) torch.Size([30, 3])

# %%
context_data_l, toforecast_data_l = data_sliding.contextwindow_testdata_generator(
    context_size=1, fcast_size=50, location='last_'
)
print(context_data_l.shape, toforecast_data_l.shape)
# Out:
# torch.Size([1, 3]) torch.Size([50, 3])

# %% [markdown]
# ##  Step 6: Initialize the LSTM Forecasting Model
#
# We now instantiate a custom `LSTM_Model` for multivariate time series forecasting.
#
# - `input_size=3`: the number of features (x, y, z of the Lorenz system)
# - `hidden_size=5`: number of hidden units in the LSTM layer
# - `output_size=3`: the model predicts all 3 variables
# - `s0_nature='random_'`: initial hidden state is randomized
# - `train_s0=True`: initial state is treated as a learnable parameter
# - `init_range=(-0.75, 0.75)`: range for initializing model weights
# - `num_layers=1`: a single LSTM layer
#
# This model will be passed to the trainer in the next step.

# %%
lstm_model = LSTM_Model(
    input_size=3, hidden_size=5, output_size=3,
    s0_nature='random_', train_s0=True, init_range=(-0.75, 0.75), num_layers=1
)

# %% [markdown]
# ## Step 7: Configure the RNN Trainer
#
# We now set up the `RNNTrainer` to manage model training, loss computation, backpropagation, and checkpointing.
#
# - `model`: the `LSTM_Model` defined earlier
# - `loss_fn`: `"logcosh"` is more robust than MSE to outliers (you can also use `"mse"`)
# - `backprop_mode`:
#   - `"per_batch"`: update weights after each batch
#   - `"per_epoch"`: accumulate loss and update once per epoch
# - `learning_rate`: controls how fast the model learns
# - `optimizer_type`: choose `"adam"` for adaptive learning or `"sgd"` for vanilla stochastic gradient descent
#
# This trainer class also handles saving the best model checkpoints and tracking loss metrics automatically.

# %%
lstm_trainer = RNNTrainer(
    model=lstm_model,
    loss_fn="logcosh",                   # Options: "mse", "logcosh"
    backprop_mode="per_batch",          # Options: "per_batch", "per_epoch"
    learning_rate=1e-4,
    optimizer_type="adam"               # Options: "adam", "sgd"
)

# %% [markdown]
# ## Step 8: Train the Model (`train_only` mode)
#
# We now train the model using the `train_only()` method:
#
# - The model will learn exclusively from training data — no validation set is involved.
# - It will run for **5 epochs**.
# - At the end of each epoch:
#   - Training loss is computed and logged.
#   - The model is saved **only if it improves** the average training loss.
# - Output:
#   - A directory under `./checkpoints_<model_name>_<timestamp>/` containing:
#     - `best_train_avg_loss.pth`: the best model weights
#     - `epoch_losses.json`: training loss per epoch in JSON format

# %%
lstm_trainer.train_only(data_loader=my_rnn_data_loader , num_epochs=5)
# Out:
# Training Only:  20%|██        | 1/5 [00:00<00:01,  2.56it/s]
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.002074). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.002175). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.002338). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.002608). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.002998). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.003344). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.003164). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.002147). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000971). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000421). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000368). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000447). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000514). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000548). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000554). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000546). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000535). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000531). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000541). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000562). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000586). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000605). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000616). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000618). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000612). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000599). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000580). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# ✅ Best average train loss so far is (0.000557). Model saved to best_train_avg_loss.pth
# [End of Epoch 1] Best train Loss: 0.000557
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.002032). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.002133). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.002293). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.002559). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.002945). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.003290). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.003119). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.002116). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000951). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000403). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000348). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000424). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000490). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000523). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000530). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000522). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000512). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000509). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000519). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000539). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000562). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000580). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000590). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000591). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000586). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000573). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000555). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# ✅ Best average train loss so far is (0.000534). Model saved to best_train_avg_loss.pth
# [End of Epoch 2] Best train Loss: 0.000534
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.001992). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.002091). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.002249). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.002511). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.002893). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.003238). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.003077). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.002088). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000932). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000386). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000328). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000402). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000467). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000499). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000507). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000500). Model saved to best_train_avg_loss.pth
# Training Only:  80%|████████  | 4/5 [00:00<00:00,  6.97it/s]
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000490). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000488). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000497). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000517). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000538). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000556). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000565). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000566). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000560). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000549). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000532). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# ✅ Best average train loss so far is (0.000511). Model saved to best_train_avg_loss.pth
# [End of Epoch 3] Best train Loss: 0.000511
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.001953). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.002050). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.002205). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.002464). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.002842). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.003187). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.003035). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.002061). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000915). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000370). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000309). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000381). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000444). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000477). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000485). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000479). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000470). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000468). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000477). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000496). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000516). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000533). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000541). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000542). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000537). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000525). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000509). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# ✅ Best average train loss so far is (0.000490). Model saved to best_train_avg_loss.pth
# [End of Epoch 4] Best train Loss: 0.000490
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.001915). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.002011). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.002164). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.002419). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.002793). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.003138). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.002994). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.002034). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000898). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000354). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000292). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000361). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000423). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000455). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000464). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000459). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000451). Model saved to best_train_avg_loss.pth
# Training Only: 100%|██████████| 5/5 [00:00<00:00,  6.61it/s]
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000449). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000458). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000476). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000496). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000511). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000519). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000519). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000514). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000503). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000488). Model saved to best_train_avg_loss.pth
# 🗑️ Removed old checkpoint: ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Checkpoint saved at ./checkpoints_LSTMModel_2025_06_08__21_57_44/LSTMModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# ✅ Best average train loss so far is (0.000469). Model saved to best_train_avg_loss.pth
# [End of Epoch 5] Best train Loss: 0.000469
# Epoch losses saved to: epoch_losses.json

# %% [markdown]
# ##  Step 9: Train with Validation (`train_validate` mode)
#
# We now switch to using the `RNN_Model` and perform **training + validation** using the `train_validate()` method:
#
# - The model trains on sliding-window training batches from `my_rnn_data_loader`.
# - After each epoch, it forecasts using:
#   - `calibration_window`: a short historical window (`context_data_r`)
#   - `val_data`: the ground-truth future to be predicted (`toforecast_data_r`)
# - The trainer compares the forecast to the ground truth and computes validation loss.
# - It saves the model if the validation performance improves.
#
# 📦 Output Artifacts:
# - `best_val_avg_loss.pth`: model with the lowest validation loss
# - `epoch_losses.json`: training and validation losses per epoch
# - `forecast_results_epoch_*.csv`: predicted vs actual sequences for each epoch

# %%
rnn_model = RNN_Model(
    input_size=3, hidden_size=5, output_size=3,
    s0_nature='random_', train_s0=True, init_range=(-0.75, 0.75), num_layers=1
)



print(rnn_model)
# Out:
# RNN_Model(
#   (state_transition_layer): RNN(3, 5, bias=False, batch_first=True)
#   (output_extraction_layer): Linear(in_features=5, out_features=3, bias=False)
# )

# %%
rnn_trainer = RNNTrainer( model=rnn_model,   loss_fn="logcosh", backprop_mode="per_epoch", learning_rate=1e-4,   optimizer_type="adam")

# %%
rnn_trainer.train_validate(   data_loader=my_rnn_data_loader,   calibration_window=context_data_r,  val_data=toforecast_data_r,  num_epochs=5 )
# Out:
# Training and validating:  60%|██████    | 3/5 [00:00<00:00, 14.86it/s]
# Checkpoint saved at ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# Forecasts saved to: forecast_results_epoch_1.csv
# ✅ New best forecast MSE: 0.000047. Model saved to best_val_avg_loss.pth
# [End of Epoch 1] Current val loss: 0.000047 || Best val Loss: 0.000047
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch1.pth
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/forecast_results_epoch_1.csv
# Checkpoint saved at ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# Forecasts saved to: forecast_results_epoch_2.csv
# ✅ New best forecast MSE: 0.000047. Model saved to best_val_avg_loss.pth
# [End of Epoch 2] Current val loss: 0.000047 || Best val Loss: 0.000047
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch2.pth
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/forecast_results_epoch_2.csv
# Checkpoint saved at ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# Forecasts saved to: forecast_results_epoch_3.csv
# ✅ New best forecast MSE: 0.000047. Model saved to best_val_avg_loss.pth
# [End of Epoch 3] Current val loss: 0.000047 || Best val Loss: 0.000047
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch3.pth
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/forecast_results_epoch_3.csv
# Checkpoint saved at ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# Forecasts saved to: forecast_results_epoch_4.csv
# ✅ New best forecast MSE: 0.000047. Model saved to best_val_avg_loss.pth
# [End of Epoch 4] Current val loss: 0.000047 || Best val Loss: 0.000047
# Training and validating: 100%|██████████| 5/5 [00:00<00:00, 15.47it/s]
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch4.pth
# 🗑️ Removed old checkpoint: ./checkpoints_RNNModel_2025_06_08__21_59_32/forecast_results_epoch_4.csv
# Checkpoint saved at ./checkpoints_RNNModel_2025_06_08__21_59_32/RNNModel_in3_hid5_out3_randInit-0.75to0.75_trainableS0_epoch5.pth
# Forecasts saved to: forecast_results_epoch_5.csv
# ✅ New best forecast MSE: 0.000047. Model saved to best_val_avg_loss.pth
# [End of Epoch 5] Current val loss: 0.000047 || Best val Loss: 0.000047
# Epoch losses saved to: epoch_losses.json
